# %% [markdown]
# # 02 - Analisis exploratorio
#
# Este notebook documenta la fase **Analyze**. El análisis reproducible y la generación de visualizaciones viven en `scripts/analyze_fitbit_data.py`.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROCESSED_DIR = PROJECT_ROOT / 'data' / 'processed'

analysis = pd.read_csv(PROCESSED_DIR / 'bellabeat_analysis_dataset.csv', parse_dates=['activity_date'])
users = pd.read_csv(PROCESSED_DIR / 'user_segments.csv')
analysis.shape, users.shape

# %%
analysis[['total_steps', 'calories', 'active_minutes', 'sedentary_minutes', 'sleep_hours']].describe()

# %%
users['user_segment'].value_counts().sort_index()

# %% [markdown]
# ## Generar reportes y visualizaciones
#
# La celda siguiente actualiza `reports/analysis_findings.md`, `reports/caso_estudio_bellabeat.md` y las imagenes en `visualizations/`.

# %%
import runpy

runpy.run_path(PROJECT_ROOT / 'scripts' / 'analyze_fitbit_data.py', run_name='__main__')
