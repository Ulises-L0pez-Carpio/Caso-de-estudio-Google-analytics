# %% [markdown]
# # 01 - Preparacion de datos
#
# Este notebook documenta la fase **Prepare** y **Process** del caso Bellabeat. El flujo reproducible vive en `scripts/prepare_fitbit_data.py` para que los archivos procesados puedan regenerarse desde cero.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DIR = PROJECT_ROOT / 'data' / 'raw'
PROCESSED_DIR = PROJECT_ROOT / 'data' / 'processed'

csv_files = sorted(RAW_DIR.rglob('*.csv'))
len(csv_files), [p.name for p in csv_files[:5]]

# %% [markdown]
# ## Ejecutar preparacion
#
# La celda siguiente ejecuta el script principal y genera los CSV limpios, el inventario de archivos y la documentacion de limpieza.

# %%
import runpy

runpy.run_path(PROJECT_ROOT / 'scripts' / 'prepare_fitbit_data.py', run_name='__main__')

# %%
analysis = pd.read_csv(PROCESSED_DIR / 'bellabeat_analysis_dataset.csv')
analysis.head()
